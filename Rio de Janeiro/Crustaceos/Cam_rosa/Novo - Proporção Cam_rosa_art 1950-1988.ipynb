# %%
import numpy as np
import pandas as pd
import keras
import matplotlib.pyplot as plt
from keras import layers
from scipy.stats.mstats import winsorize
# Out:
# 2024-08-02 12:47:15.083880: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-08-02 12:47:15.121725: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-02 12:47:15.648392: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Coletando dados

df = pd.read_excel('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Crustaceos/RJ_Reconstrucao_Crustaceos_2024_06_25.xlsx')

df_Camaroes = df[['Ano','Cam_sete_barbas_art', 'Cam_branco_art', 'Cam_rosa_art', 'Cam_barba_ruca_art']].dropna().reset_index(drop=True)


dados = df_Camaroes[['Ano','Cam_rosa_art']]
for i in range(len(dados['Ano'])):
  dados.loc[i,'Soma'] = df_Camaroes.loc[i,'Cam_sete_barbas_art']+df_Camaroes.loc[i,'Cam_branco_art']+df_Camaroes.loc[i,'Cam_rosa_art']+df_Camaroes.loc[i, 'Cam_barba_ruca_art']
  
dados = dados[['Ano','Cam_rosa_art','Soma']]

#Fazendo as proporções
for i in range(len(dados['Ano'])):
  dados.loc[i,'Prop_Cam_rosa_art'] = dados.loc[i,'Cam_rosa_art'] / dados.loc[i,'Soma']


anos_com_dados = dados["Ano"].values
anos_para_prever = np.array([1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988])
todos_anos = np.concatenate((anos_para_prever, anos_com_dados))
todos_anos.sort()

prop = dados['Prop_Cam_rosa_art'].values
dados.head()
# Out:
# /tmp/ipykernel_36084/2235033211.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados.loc[i,'Soma'] = df_Camaroes.loc[i,'Cam_sete_barbas_art']+df_Camaroes.loc[i,'Cam_branco_art']+df_Camaroes.loc[i,'Cam_rosa_art']+df_Camaroes.loc[i, 'Cam_barba_ruca_art']
#     Ano  Cam_rosa_art    Soma  Prop_Cam_rosa_art
# 0  1981          35.0  1719.0           0.020361
# 1  1982          89.0  2170.0           0.041014
# 2  1983         806.0  4077.0           0.197694
# 3  1984         525.0  5993.0           0.087602
# 4  1985         569.0  5281.0           0.107745

# %%
#Normalização dos dados

ano_mean = np.mean(anos_com_dados)
ano_std = np.std(anos_com_dados)
anos_para_prever_norm = (anos_para_prever - ano_mean)/ano_std
anos_com_dados_norm = (anos_com_dados - ano_mean)/ano_std

prop_mean = np.mean(prop)
prop_std = np.std(prop)
prop_norm = (prop - prop_mean)/prop_std

# %%
#Fit do modelo e salvando seus pesos
model = keras.Sequential([layers.Dense(96,activation='leaky_relu',input_shape=(1,)),
                             layers.Dense(32,activation='leaky_relu'),
                             layers.Dense(80,activation='leaky_relu'),
                             layers.Dense(80,activation='leaky_relu'),
                             layers.Dense(96,activation='leaky_relu'),
                             layers.Dense(112,activation='leaky_relu'),
                             layers.Dense(1,activation='linear')])

opt = keras.optimizers.Nadam(learning_rate=0.001)
model.compile(optimizer=opt, loss='mse')


history = model.fit(anos_com_dados_norm,prop_norm, epochs=100, verbose=1)
model.save_weights('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Crustaceos/Cam_rosa/pesos prop art 1950-1988/.weights.h5', overwrite=True)
# Out:
# Epoch 1/100
# /home/andre/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 978ms/step - loss: 0.9974
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9790
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9660
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9530
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9405
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9289
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9191
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9117
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9063
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9037
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9024
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9006
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8985
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8964
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8941
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8917
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8888
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8859
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8822
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8787
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8743
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8691
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8634
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8554
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8508
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8495
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8331
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8234
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8130
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8034
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7916
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7851
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7734
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7569
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7400
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7196
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7020
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6851
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6783
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6496
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6443
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6022
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5875
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5581
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5521
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5199
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5217
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4754
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4671
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4344
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4405
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4122
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4276
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3809
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3754
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3505
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3464
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3325
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3433
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3316
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3453
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3149
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3135
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2984
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2913
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2831
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2795
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2695
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2654
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2605
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2572
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2538
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2538
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2521
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2503
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2525
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2414
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2404
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2337
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2325
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2304
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2392
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2307
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2362
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2253
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2238
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2212
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2287
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2204
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2233
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2126
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2100
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2080
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.2057
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2038
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2036
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2077
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2239
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2135
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.2238

# %%
model.load_weights('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Crustaceos/Cam_rosa/pesos prop art 1950-1988/.weights.h5')

# %%
#Previsões
prev_disponiveis = model.predict(anos_com_dados_norm)*prop_std + prop_mean
prev_ausentes = model.predict(anos_para_prever_norm)*prop_std + prop_mean

#Colocando valores negativos para 0
for i in range(len(prev_ausentes)):
    if prev_ausentes[i]<0:
        prev_ausentes[i]=0
    if prev_ausentes[i]>1:
        prev_ausentes[i]=1

#Plot dos dados e previsões
f1=plt.figure(1).add_subplot()
f1.scatter(anos_com_dados,prop,label='Dados disponíveis')
f1.scatter(anos_para_prever,prev_ausentes, color='red', label='Previsões dos dados ausentes')

#Plot do fit da rede
p = np.linspace(-2,2,50)
y = model.predict(p)*prop_std + prop_mean
f1.plot(p*ano_std + ano_mean,y,color='orange',label='Fit da rede')

#Print das previsões
print('Previsões dos dados ausentes:', prev_ausentes)


plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Previsões dos dados ausentes: [[0.02291287]
#  [0.0247893 ]
#  [0.02666568]
#  [0.02855158]
#  [0.03043479]
#  [0.03230421]
#  [0.03416454]
#  [0.03593265]
#  [0.03769776]
#  [0.0394628 ]
#  [0.04121771]
#  [0.0429592 ]
#  [0.04470083]
#  [0.04646692]
#  [0.04821447]
#  [0.04996201]
#  [0.05170958]
#  [0.05345712]
#  [0.05520482]
#  [0.05695255]
#  [0.05868886]
#  [0.06040587]
#  [0.0621277 ]
#  [0.06390554]
#  [0.0656833 ]
#  [0.06745645]
#  [0.06921544]
#  [0.07099313]
#  [0.07277732]
#  [0.07456344]
#  [0.07637694]
#  [0.07820778]
#  [0.08008815]
#  [0.08205143]
#  [0.08392504]
#  [0.08562307]
#  [0.08703536]
#  [0.08834428]
#  [0.08962686]]

# %%
loss = history.history['loss']
plt.plot(loss,label='loss')
plt.legend()
plt.show()

# %%
#Lista de anos sem buracos normalizada e sua predição      (para poder me referir por indices)

anos = np.arange(1950,np.max(anos_para_prever)+1)
anos_norm = (anos-ano_mean)/ano_std
prev_continua = model.predict(anos_norm)*prop_std + prop_mean

for i in range(len(prev_continua)):
    if prev_continua[i]<0:
        prev_continua[i]=0
    if prev_continua[i]>=1:
        prev_continua[i]=1

np.save('prev_continua_Cam_rosa_art 1950-1988',prev_continua)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
