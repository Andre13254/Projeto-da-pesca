# %%
import numpy as np
import pandas as pd

# %%
#Proporções das especies que receberao valores da desagregação
prop_Pesc_goete_ind_1962_2015= np.load('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Peixes/Sciaenidae/Desagregações Pescada_ind 1962-2015/prev_Pesc_goete_ind.npy').flatten()
prop_Pesc_amarela_ind_1962_2015= np.load('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Peixes/Sciaenidae/Desagregações Pescada_ind 1962-2015/prev_Pesc_amarela_ind.npy').flatten()
prop_Pesc_bicuda_ind_1962_2015=np.load('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Peixes/Sciaenidae/Desagregações Pescada_ind 1962-2015/prev_Pesc_bicuda_ind.npy').flatten()
prop_Pesc_branca_ind_1962_2015= np.load('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Peixes/Sciaenidae/Desagregações Pescada_ind 1962-2015/prev_Pesc_branca_ind.npy').flatten()
prop_Pesc_cambucu_ind_1962_2015=np.load('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Peixes/Sciaenidae/Desagregações Pescada_ind 1962-2015/prev_Pesc_cambucu_ind.npy').flatten()
prop_Pesc_olhuda_ind_1962_2015= np.load('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Peixes/Sciaenidae/Desagregações Pescada_ind 1962-2015/prev_Pesc_olhuda_ind.npy').flatten()
prop_Pesc_banana_ind_1962_2015= np.load('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Peixes/Sciaenidae/Desagregações Pescada_ind 1962-2015/prev_Pesc_banana_ind.npy').flatten()

# %%
#Soma das proporções
prop_soma = prop_Pesc_goete_ind_1962_2015 + prop_Pesc_amarela_ind_1962_2015 + prop_Pesc_bicuda_ind_1962_2015  + prop_Pesc_branca_ind_1962_2015 + prop_Pesc_cambucu_ind_1962_2015 + prop_Pesc_olhuda_ind_1962_2015 + prop_Pesc_banana_ind_1962_2015

#Dividindo proporções pela soma para que de sempre 1
for i in range(len(prop_Pesc_goete_ind_1962_2015)):
  prop_Pesc_goete_ind_1962_2015[i] /= prop_soma[i] 
  prop_Pesc_amarela_ind_1962_2015[i] /= prop_soma[i]
  prop_Pesc_bicuda_ind_1962_2015 [i] /= prop_soma[i]
  prop_Pesc_branca_ind_1962_2015[i] /= prop_soma[i]
  prop_Pesc_cambucu_ind_1962_2015[i] /= prop_soma[i]
  prop_Pesc_olhuda_ind_1962_2015[i] /= prop_soma[i]
  prop_Pesc_banana_ind_1962_2015[i] /= prop_soma[i]

# %%
df_prev = pd.read_excel('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Peixes/Sciaenidae/RJ_Reconstrucao_Sciaenidae_2024_08_06.xlsx')
df_prev = df_prev[['Ano','Pesc_goete_ind','Pesc_amarela_ind','Pesc_bicuda_ind','Pesc_branca_ind','Pesc_cambucu_ind','Pesc_olhuda_ind','Pesc_banana_ind']]


df_Pescada_ind = pd.read_excel('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Peixes/Sciaenidae/Desagregações Pescada_ind 1962-2015/Previsão Pescada_ind_1962-1977.xlsx')
df_Pescada_ind = df_Pescada_ind[['Ano','Pescada_ind']]

anos_para_prever = np.array([1962,1963,1964,1966,1967,1968,1969,1970,1971,1972,1973,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])

for i in range(len(prop_Pesc_goete_ind_1962_2015)):
    if i+1950 in anos_para_prever:
      df_prev.loc[i,'Pesc_goete_ind'] = df_Pescada_ind.loc[i,'Pescada_ind']*prop_Pesc_goete_ind_1962_2015[i]
      df_prev.loc[i,'Pesc_amarela_ind'] = df_Pescada_ind.loc[i,'Pescada_ind']*prop_Pesc_amarela_ind_1962_2015[i]
      df_prev.loc[i,'Pesc_bicuda_ind'] = df_Pescada_ind.loc[i,'Pescada_ind']*prop_Pesc_bicuda_ind_1962_2015[i]
      df_prev.loc[i,'Pesc_branca_ind'] = df_Pescada_ind.loc[i,'Pescada_ind']*prop_Pesc_branca_ind_1962_2015[i]
      df_prev.loc[i,'Pesc_cambucu_ind'] = df_Pescada_ind.loc[i,'Pescada_ind']*prop_Pesc_cambucu_ind_1962_2015[i]
      df_prev.loc[i,'Pesc_olhuda_ind'] = df_Pescada_ind.loc[i,'Pescada_ind']*prop_Pesc_olhuda_ind_1962_2015[i]
      df_prev.loc[i,'Pesc_banana_ind'] = df_Pescada_ind.loc[i,'Pescada_ind']*prop_Pesc_banana_ind_1962_2015[i]


df_prev = df_prev.loc[1962-1950:,:]
with pd.option_context('display.max_rows', None,):
   print(df_prev)

df_prev.to_excel('/home/andre/Área de Trabalho/Reconstrução da Estatística Pesqueira BR/Rio de Janeiro/Peixes/Sciaenidae/Desagregações Pescada_ind 1962-2015/Desagregação Pescada_ind 1962-2015.xlsx')
# Out:
#      Ano  Pesc_goete_ind  Pesc_amarela_ind  Pesc_bicuda_ind  Pesc_branca_ind  \
# 12  1962       48.515829          0.220311         0.137463         0.409371
# 13  1963       71.736056          0.325754         0.203254         0.605301
# 14  1964      115.805709          0.525875         0.328119         0.977156
# 15  1965             NaN               NaN              NaN              NaN
# 16  1966       42.091995          0.191140         0.119262         0.355168
# 17  1967      111.215675          0.505031         0.315114         0.938426
# 18  1968      285.701986          1.297375         0.809496         2.410722
# 19  1969      191.440368          0.869332         0.542419         1.615353
# 20  1970      173.173179          0.786381         0.490662         1.461216
# 21  1971      225.673345          1.024785         0.639413         1.904207
# 22  1972      168.422123          0.764806         0.477200         1.421127
# ...
